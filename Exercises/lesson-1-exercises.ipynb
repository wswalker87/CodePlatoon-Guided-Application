# %% [markdown]
# ## Python Syntax Basics
#
# #### Exercise 1:
#
# Write a Python script that prints the following:
#
#     "Hello, Python World!"

# %%
# Add your code here
print("Hello, Python World!")
# Expected output: "Hello, Python World!"
# Out:
# Hello, Python World!

# %% [markdown]
# #### Exercise 2:
#
# Fix the syntax errors in the following code snippet:

# %%
print("Welcome to Python!")
print('Learning Python is fun!')

# Expected output: "Welcome to Python!"
#                  "Learning Python is fun!"
# Out:
# Welcome to Python!
# Learning Python is fun!

# %% [markdown]
# #### Exercise 3:
#
# Write a Python script that prints your name and age on seperate lines

# %%
# Add your code here
name = "Scott"
age = 37
print(f"{name}\n{age}")
# Expected output: "Billy"
#                  "47"
# Out:
# Scott
# 37

# %% [markdown]
# ## Variables
#
# #### Exercise 1:
# Create a variable called my_name and assign it your name as a String. Then print the value of my_name.

# %%
# Add your code here
my_name = "Scott"
print(my_name)

# Expected output: "Billy"
# Out:
# Scott

# %% [markdown]
# #### Exercise 2:
#
# Create two variables, x and y, and assign them numbers. Print their sum.

# %%
# Add your code here
x = 6
y = 5
print(f"The sum of x and y is {x + y}")
# Out:
# The sum of x and y is 11

# %% [markdown]
# #### Exercise 3:
#
# Create a variable of your liking. Change the value of the variable and print both the old and new values.

# %%
# Add your code here
your_liking = 8
print(your_liking)
your_liking = 16
print(your_liking)
# Out:
# 8
# 16

# %% [markdown]
# ## Constants
#
# #### Exercise 1:
#
# Define a constant variable named PI with the value of "pi". Print its value.

# %%
# Add your code here
PI = 3.14
print(PI)
# Out:
# 3.14

# %% [markdown]
# #### Exercise 2:
#
# Write a script that uses a constant to calculate the circumference of a circle (C = 2 * PI * radius). Use 5 as the radius

# %%
# Add your code here
PI = 3.14
radius = 5
C = 2 * PI * radius
print(f"C = {C}")
# Out:
# C = 31.400000000000002

# %% [markdown]
# ## Data Types
#
# #### Exercise 1:
#
# Identify the data type of each of the following values and print the results:
#
# * 42
# * 3.14
# * 'Hello'
# * True

# %%
# Add your code here
print(type(42))
print(type(3.14))
print(type('Hello'))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# #### Exercise 2:
#
# Convert an Integer to a float and a float to an integer. Print the results

# %%
# Add your code here
treebeard = 42
print(float(treebeard))
# Out:
# 42.0

# %% [markdown]
# ## Casting
#
# #### Exercise 1:
#
# Write a script that converts the string '123' to an integer and adds 10 to it. Print the result as well as the type. Convert it back to a String and print out the type.

# %%
# Add your code here
string123 = '123'
int123 = int(string123)
total = int123 + 10
print(total)
print(type((int123 + 10)))
total_string = str(total)
print(type(total_string))
# Out:
# 133
# <class 'int'>
# <class 'str'>

# %% [markdown]
# #### Exercise 2:
#
# Convert a float to a string and concatenate it with another string. For example:
#
#     The price is 9.99

# %%
# Add your code here
mm = str(19.99)
print("For the low low price of " + mm)
# Out:
# For the low low price of 19.99

# %% [markdown]
# #### Exercise 3:
#
# Take input from the user as a string, cast it to an integer, and double its value. Print the result.

# %%
# Add your code here
user_inputA = input("What number should we double?: ")
#user_inputA = 5
print(f'Ok, we will double {user_inputA}')
doubled = ((user_inputA) * (2))
print(f'{user_inputA} times 2 is equal to {doubled}')

# %% [markdown]
# ## Booleans
#
# #### Exercise 1:
#
# Create two variables, a and b, with the values 10 and 20. Write a script that checks if a is greater than b and prints the result.

# %%
# Add your code here
a = 10 
b = 20
if a < b:
    print(f"{a} is less than {b}")
else:
    print(f"{b} is greater than {a}")
# Out:
# 10 is less than 20

# %% [markdown]
# #### Exercise 2:
#
# Write a a script that evaluates the boolean value of different data types, such as 0, 1, "", and "hello".

# %%
# Add your code here
string_id = "hello"
float_id = 0
int_id = 1
print(bool(string_id))
print(bool(float_id))
print(bool(int_id))
# Out:
# True
# False
# True

# %% [markdown]
# #### Exercise 3:
#
# Write a simple script that checks if a number is even and prints True if it is, otherwise False.

# %%
# Add your code here
user_number = input(f"Input a number to check if it is even of odd:")
if int(user_number) % 1:
    print(f"{user_number} is even.")
else:
    print(f"{user_number} is odd.")
# Out:
# 6 is odd.

# %% [markdown]
# ## Numbers
#
# #### Exercise 1:
#
# Write a script that calculates the sqaure and cube of a number and prints both results.

# %%
# Add your code here
user_numberB = input(f"Supply a number to square and cube:")
squared = (int(user_numberB)**2)
cubed = (int(user_numberB)**3)
print(f"{user_numberB} squared is {squared} and {user_numberB} cubed is {cubed}.")
# Out:
# 5 squared is 25 and 5 cubed is 125.

# %% [markdown]
# #### Exercise 2:
#
# Write a script to swap the values of two numbers using a variable

# %%
# Add your code here

# %% [markdown]
# #### Exercise 3:
#
# Calculate the area of a triangle with base 5 and height 10.

# %%
# Add your code here
# formula is A = (HB)/2
area = 0
height = 10
base = 5

area = (height * base)/2
print(area)
# Out:
# 25.0

# %% [markdown]
# ## Mathematical Operators
#
# #### Exercise 1:
#
# Write a script that calculates the result of 10 + 5, 10 - 5, 10 * 5, and 10 / 5.
#
# Print each result

# %%
# Add your code here
a = 10 
b = 5
sum = a + b
diff = a - b
prod = a * b
div = a / b
print(f"{a + b} {a - b} {a * b} {a / b}")
# Out:
# 15 5 50 2.0

# %% [markdown]
# #### Exercise 2:
#
# Write a script to calculate the remainder of dividing 15 by 4

# %%
# Add your code here
remainder = 15 % 4
print(remainder)
# Out:
# 3

# %% [markdown]
# #### Exercise 3:
#
# Use the floor division operator to divide 17 by 3 and print the result

# %%
# Add your code here
floor = 17 // 3
print(floor)
# Out:
# 5

# %% [markdown]
# ## Identifying Relevant Data and Processes
#
# #### Exercise 1:
#
# Write a program that asks the user for their age and calculates how many years until they turn 100.

# %%
# Add your code here
age = input("What is your age?")
age_num = int(age)
time_to_century = (100 - age_num)
print(f"You will turn 100 in {time_to_century} years")
# Out:
# You will run 100 in 80 years

# %% [markdown]
# #### Exercise 2:
#
# Ask the user for their height in centimeters and convert it to meters. Print the result.

# %%
# Add your code here
user_height = input("What is your height in centimeters?")
user_height_cm = int(user_height)
user_height_m = (user_height_cm * 100)
print(f"Your height in meters is {user_height_m}")
# Out:
# Your height in meters is 6200

# %% [markdown]
# #### Exercise 3:
#
# Write a program that takes the user's weight in kilograms and height in meters and calculates their BMI. Metric units: BMI = weight (kg) / [height (m)]2

# %%
# Add your code here
user_weight = input("What is your weight in kilograms?")
user_height = input("What is your height in meters?")
user_weight_kg = int(user_weight)
user_height_m = int(user_height)
bmi = (user_weight_kg / user_height_m)*2
print(f"Your BMI is {bmi}")
# Out:
# Your BMI is in meters is 6.666666666666667

# %% [markdown]
# ## Strings
#
# #### Exercise 1:
#
# Write a script that concatenates two strings and prints the result

# %%
# Add your code here
string1 = "This is string 1"
string2 = "This is string 2"
print(string1 + " " + string2)
# Out:
# This is string 1 This is string 2

# %% [markdown]
# #### Exercise 2:
#
# Take a user input string of them introducing themselves and print the length of the string

# %%
# Add your code here
user_intro = input("My name is Scott. Nice to meet you.")
print(len(user_intro))
# Out:
# 12

# %% [markdown]
# #### Exercise 3:
#
# Write a script that prints a string containing double quotes and single quotes, such as
#
#     She said, "Python is 'awesome'!"

# %%
# Add your code here
print("She said, \"Python is 'awesome'!\"")
# Out:
# She said, "Python is 'awesome'!"

# %% [markdown]
# ## Slicing Strings
#
# #### Exercise 1:
#
# Write a script that extracts the first 5 characters from a string and prints them.

# %%
# Add your code here
slice_this = "This is a string that needs sliced"
print(slice_this[0:4])
# Out:
# This

# %% [markdown]
# #### Exercise 2:
#
# Slice and print the last 3 characters of a string

# %%
# Add your code here
slice_this = "This is a string that needs sliced backwards"
print(slice_this[-3:])
# Out:
# rds

# %% [markdown]
# ## String Operations and Methods
#
# #### Exercise 1:
#
# Convert a string to uppercase and print it

# %%
# Add your code here
make_it_big = "this was in all lower-case"
print(make_it_big.upper())
# Out:
# THIS WAS IN ALL LOWER-CASE

# %% [markdown]
# #### Exercise 2:
#
# Write a script that finds the position of a specific character in a string

# %%
# Add your code here
find_the_why = "We need to know the why!"
print(find_the_why.find("y"))
# Out:
# 22

# %% [markdown]
# #### Exercise 3:
#
# Split a sentence in a list of words and print the list

# %%
# Add your code here
separate_it = "Apple banana cucumber date"
fruit_list = separate_it.split(" ")
print(fruit_list)
# Out:
# ['Apple', 'banana', 'cucumber', 'date']

# %% [markdown]
# ## Interpolated Strings
#
# #### Exercise 1:
#
# Use an f-string to print the following:
#
#     My name is [your name] and I am [your age] years old.

# %%
# Add your code here
your_name = "Bill"
your_age = 22
print(f"My name is {your_name} and I am {your_age} years old")
# Out:
# My name is Bill and I am 22 years old

# %% [markdown]
# #### Exercise 2:
#
# Write a script that uses an f-string to format and print a math equation, such as:
#
#     5 + 3 = 8

# %%
# Add your code here
print(f"5 + 3 = 8")
# Out:
# 5 + 3 = 8

# %% [markdown]
# #### Exercise 3:
#
# Take two user inputs, a name and a favorite color, and print a sentence using an f-string

# %%
# Add your code here
name = input("What's your name?")
fav_color = input("What's your favorite color?")
print(f"Hi {name}. I also like {fav_color}.")
# Out:
# Hi Scott. I also like Green.
